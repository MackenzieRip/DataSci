# %% [markdown]
# <a href="https://colab.research.google.com/github/MackenzieRip/DataSci/blob/main/Mackenzie_Ripley_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4])

# %%
# population

# %%
np.sum(x)
# Out:
# 10

# %%
x.shape[0]
# Out:
# 4

# %%
np.sum(x)/x.shape[0]
# Out:
# 2.5

# %%
def mean(x):
    return np.sum(x)/x.shape[0]   #defining mean

# %%
mean(x)
# Out:
# 2.5

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
x - mean(x)
# Out:
# array([-1.5, -0.5,  0.5,  1.5])

# %%
(x - mean(x))**2
# Out:
# array([2.25, 0.25, 0.25, 2.25])

# %%
 def var(x):
    return mean((x - mean(x))**2)  #defining var

# %%
def std(x):
    return np.sqrt(var(x))  #defining std

# %%
mean(x)    #the mean
# Out:
# 2.5

# %%
var(x)   #the var
# Out:
# 1.25

# %%
std(x)
# Out:
# 1.118033988749895

# %% [markdown]
# ### Random Number Generator

# %% [markdown]
# $y=mx+b$

# %%
m = 75                 # multiplier
b = 74                 # increment
n = 65537              # modulus

# %%
x = 58      # seed value

# %%
X = np.zeros(50000,)

# %%
x = (m * x + b) % n

# %%
for i in range(X.shape[0]):

    x = (m * x + b) % n
    
    X[i] = x

# %%
X
# Out:
# array([ 4189., 52101., 40966., ..., 26762., 41114.,  3385.])

# %%
X /= np.max(X)

# %%
plt.plot(X[:100],'.')    #a plot of 100 dots

# %%
plt.hist(X);  #a histogram

# %%
plt.hist(X,100);

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,)

# %%
X
# Out:
# array([0.99503542, 0.578975  , 0.67734831, ..., 0.57919365, 0.68830843,
#        0.95878626])

# %%
plt.hist(X,100);

# %%
np.random.random()
# Out:
# 0.7236503564492759

# %%
r = np.random.random()  #defining r

# %%
r
# Out:
# 0.7029425290727437

# %%
r = np.random.randint(1,10)  #r is between 1 and 10

# %%
r
# Out:
# 4

# %%
r = np.random.randint(0,3,size=(1))

# %%
r[0]
# Out:
# 2

# %%
game = ['rock', 'paper', 'scissors']  #defining game

# %%
game[r[0]]
# Out:
# 'scissors'

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]

# %%
p1,p2
# Out:
# (2, 0)

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]
game[p1],game[p2]
# Out:
# ('scissors', 'scissors')

# %%
import numpy as np

# %%
np.random.randn()
# Out:
# 0.04208671543043578

# %%
numbers  = np.random.randn(2,4)

# %%
numbers.shape
# Out:
# (2, 4)

# %%
numbers = numbers.reshape(-1)

# %%
numbers.shape
# Out:
# (8,)

# %%
# numbers= np.array([1,2,2,3,3,3,4,4,4,4])

# %%
numbers = np.random.randn(100000,)

# %%
numbers.shape
# Out:
# (100000,)

# %%
plt.hist(numbers,100);  #histogram of rock paper scissor probabilities out of 100 games

# %%
numbers = np.random.rand(1000000,)

# %%
plt.hist(numbers,100);

# %%
np.random.seed(12345)
data = np.random.randn(2, 100)

plt.figure(1, figsize=(9, 9))


plt.subplot(2,2,1)       #plotting histogram
plt.hist(data[0])

plt.subplot(2,2,2)
plt.scatter(data[0], data[1])   #plotting scatter plot

plt.subplot(2,2,3)
plt.plot(data[0], data[1])

plt.subplot(2,2,4)
plt.hist2d(data[0], data[1])

plt.show()

# %% [markdown]
# Normal Dist Data

# %%
x = 50*np.random.randn(10000)

# %%
plt.hist(x);

# %%
x = np.random.rand(1000,)

# %%
plt.hist(x**2);  #ploting when x is squared

# %%
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# %%
n,bins,patches = plt.hist(x)

# %%
bins
# Out:
# array([ 47.67401067,  58.75290006,  69.83178945,  80.91067884,
#         91.98956823, 103.06845762, 114.14734702, 125.22623641,
#        136.3051258 , 147.38401519, 158.46290458])

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y)

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %%
def mean(x):                         #defining mean
    return np.sum(x)/x.shape[0]

# %%
def var(x):                         #defining var
    return mean((x - mean(x))**2)

# %%
def std(x):                           #definint std
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 100.08288406198832

# %%
std(x)
# Out:
# 14.975014354444243

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %%
x = np.linspace(-10,10,100)
y = 2.71**(-x**2)
plt.plot(x,y)

# %% [markdown]
# $e^{-x^2}$

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
def normal_pdf(x,mu,sigma):
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2))

# %%
x = np.linspace(-6,6,1000)

# %%
mu = 0  #defining mu as 0

# %%
sigma = 1   #defining sigma as 1

# %%
pdf = normal_pdf(x,mu,sigma) #Use Normal for demo, replace with custom function pdf

# %%
plt.plot(x,pdf,'.')
plt.plot(x,y,'g.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-8c92baab425f> in <module>
# ----> 1 plt.plot(x,pdf,'.')
#       2 plt.plot(x,y,'g.')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# ...

# %%
def partial_sums(x):

  y = np.zeros(x.shape)
  
  for n in range(x.shape[0]):
    
    y[n] = np.sum(x[0:n])
    
  y = y / np.max(y)
    
  return y

# %%
cdf = partial_sums(pdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-118-54ad15a18bc6> in <module>
# ----> 1 cdf = partial_sums(pdf)
#
# NameError: name 'partial_sums' is not defined

# %%
plt.plot(x,cdf,'.');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-5d4aa31a07fb> in <module>
# ----> 1 plt.plot(x,cdf,'.');
#
# NameError: name 'cdf' is not defined

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
plt.plot(cdf,x,'.');

# %%
def find_nearest(array, value):

  idx = np.argmin(np.abs(array - value))
  
  return idx

# %%
find_nearest(cdf, 0.1)

# %%
x[393]

# %%
xr = np.random.random((10000,))

# %%
w = np.zeros(xr.shape[0])

for i in range(xr.shape[0]):
  
  w[i] = x[find_nearest(cdf, xr[i])]

# %%
w.shape

# %%
plt.hist(w,50);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-c72744b82856> in <module>
# ----> 1 plt.hist(w,50);
#
# NameError: name 'w' is not defined

# %%
num_bins = 50
n,bins,patches = plt.hist(w, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %% [markdown]
# # Random Color

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.random.randint(0,255,size=(1,1,3))   #defining z

# %%
z
# Out:
# array([[[237,  95, 244]]])

# %%
z = np.random.randint(0,255,size=(10,10,3))

# %%
plt.imshow(z) #plot of random colors

# %%
z = np.zeros((10,10,3))

# %%
z.shape
# Out:
# (10, 10, 3)

# %%
plt.imshow(z)  #plotting z

# %%
z = 0*np.ones((10,10,3))

# %%
plt.imshow(z)

# %%
z = 255*np.ones((10,10,3))

# %%
plt.imshow(z)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3))

z[:,:,0] = 1                
z[:,:,1] = 0                       #making red
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 1                #making lime green
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 0                #making blue
z[:,:,2] = 1

plt.imshow(z)

# %%
plt.hist(np.random.randn(1000,)/6 + 1/2)
# Out:
# (array([  6.,  14.,  84., 169., 265., 236., 156.,  51.,  16.,   3.]),
#  array([-0.04621692,  0.06560906,  0.17743504,  0.28926102,  0.40108699,
#          0.51291297,  0.62473895,  0.73656493,  0.84839091,  0.96021689,
#          1.07204287]),
#  <a list of 10 Patch objects>)

# %%
for _ in range(100):
    z = np.ones((10,10,3))

    r = np.random.randn()/6 + 1/2
    g = np.random.randn()/6 + 1/2
    b = np.random.randn()/6 + 1/2

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.4882755916278306 0.4721761965877632 0.6596420443166704
# 0.5235979212726697 0.386464824011359 0.7879161815920346
# 0.33924616460796375 0.7647783107651203 0.6603572381230738
# 0.4570023296737363 0.5110362806015584 0.790318319912833
# 0.3917307977972807 0.6052588407411574 0.7351520139930801
# 0.12882010631540536 0.31316596152037246 0.6248219297023176
# 0.6366611858009822 0.5154460874600352 0.14210764163341955
# 0.7092320378536864 0.5666158374132985 0.2170265142414441
# 0.540798809708156 0.38208118823152587 0.5436399219625596
# 0.2978912979893854 0.47587397274519594 0.4573671451651986
# 0.4453888000241325 0.4237050009695633 0.40704668499426006
# 0.40393519828085084 0.6215393808979712 0.31147805790575656
# 0.8744878373951157 0.2007842683664935 0.5056184994626577
# 0.292858279585008 0.5181138095696599 0.21970732017232392
# ...

# %%
for i in range(100):

    z = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()            #plotting 100 different random colors

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
    plt.show()
# Out:
# 0.5495457409086235 0.5194508542708564 0.8021318414793337
# 0.5225177098530036 0.6722095186983748 0.894541156154191
# 0.38097428436597724 0.5783739117754161 0.060850526431590946
# 0.49847031428642696 0.10448484111106127 0.6752339269492466
# 0.8760165561122473 0.5500514400518673 0.538787715257654
# 0.8291208477880404 0.6777728704472057 0.4456721087343105
# 0.24883576405046903 0.3153639674250587 0.17171461732628368
# 0.9432628513201403 0.8266059650219404 0.8278397433388008
# 0.9002138287449507 0.11693292721090409 0.7941131436097298
# 0.34845663986822384 0.6577442934549104 0.7147136641309416
# 0.13138374093091543 0.08533120493657143 0.13873113532127557
# 0.698745947766959 0.4700605891571763 0.987534484361605
# 0.5521885916468396 0.40364499271096443 0.10169159760259439
# 0.6449355143459065 0.041366018852335484 0.7679630084918336
# 0.7532860953587517 0.5109519132354919 0.7679712506380831
# 0.8966585862713083 0.15033702598985998 0.3323403668640156
# ...

# %%
z1 = np.ones((10,10,3))
z1[:,:,0] = np.random.rand()
z1[:,:,1] = np.random.rand()
z1[:,:,2] = np.random.rand()

z2 = np.ones((10,10,3))
z2[:,:,0] = np.random.rand()
z2[:,:,1] = np.random.rand()              #ploting a color pallet
z2[:,:,2] = np.random.rand()

zavg = (z1+z2)/2

z1a = (z1+zavg)/2
z2a = (z2+zavg)/2

z3 = np.hstack((z1,z1a,zavg,z2a,z2))

plt.imshow(z3);
plt.show()

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()           #ploting 100 color pallets
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    zavg = (z1+z2)/2

    z1a = (z1+zavg)/2
    z2a = (z2+zavg)/2

    z3 = np.hstack((z1,z1a,zavg,z2a,z2))

    plt.imshow(z3);
    plt.show()

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()                 #plottinf 100 different color contrasts

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib
import imageio
from PIL import Image

def get_colors_lospec(url):
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %%
url = 'https://lospec.com/palette-list/agb-32x.png' #url to a color palette

# %%
url = 'https://lospec.com/palette-list/agb-1x.png'#url to color palette

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png' #url to color palette

# %%
im = imageio.imread(url)  #reads urls

# %%
plt.imshow(im); #color palette plot

# %%
z = np.random.randint(0,255,size=(10,10)) #defining z as above color plot

# %%
plt.imshow(z, cmap=get_colors_lospec(url))    #a 10 by 10 color plot unsing z
plt.colorbar();

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sqrt(x**2 + y**2)
                                                    #a different type of plot using z
plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)*np.sin(3*x)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
