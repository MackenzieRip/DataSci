# %% [markdown]
# <a href="https://colab.research.google.com/github/MackenzieRip/DataSci/blob/main/Mackenzie_Ripley_Lab_6_Cereal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv','cereal_data.csv')  #retriving url
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f7ad93ffa60>)

# %%
cereal_data = pd.read_csv('cereal_data.csv')   #defining cereal_data

# %% [markdown]
# Name: Name of cereal
#
# mfr: Manufacturer of cereal
#
#     A = American Home Food Products
#
#     G = General Mills
#
#     K = Kelloggs
#
#     N = Nabisco
#
#     P = Post
#
#     Q = Quaker Oats
#
#     R = Ralston Purina
#
# type:
#
#     cold
#
#     hot
#
# calories: calories per serving
#
# protein: grams of protein
#
# fat: grams of fat
#
# sodium: milligrams of sodium
#
# fiber: grams of dietary fiber
#
# carbo: grams of complex carbohydrates
#
# sugars: grams of sugars
#
# potass: milligrams of potassium
#
# vitamins: vitamins and minerals - 0, 25, or 100,
# indicating the typical percentage of FDA recommended
#
# shelf: display shelf (1, 2, or 3, counting from the floor)
#
# weight: weight in ounces of one serving
#
# cups: number of cups in one serving
#
# rating: a rating of the cereals

# %%
cereal_data  #showing the cereal data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_data["sugars"].mean()  #showing the mean of the sugars in the cereals
# Out:
# 6.922077922077922

# %%
cereal_data[["calories", "sugars"]].mean()  #showing the mean of the calories and sugars in the cereals
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe()   #describing the cereal data
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
cereal_data[["calories", "sugars"]]  #showing the sugar and calories data from the cereals
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.')  #plotting the cereal sugars and calories data in a scatter plot

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')  #plotting the cereal fat and calories data in a scatter plot

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')    #plotting the cereal fat and calories data in a scatter plot

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["carbo"]],'.')   #plotting the cereal sugars and carbo data in a scatter plot

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["vitamins"]],'.')   #plotting the cereal sugars and vitamins data in a scatter plot

# %%
X = cereal_data[["sugars"]]    #Defining x
Y = cereal_data[["calories"]]  #Defining y

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

# %%
plt.plot(X, Y,'.')  #plotting x and y in a scatter plot
plt.plot(X, Y_pred, color='red')  #making the line color red
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,50)  #defining x

# %%
noise = 10 * np.random.randn(50,)  #defining noise

# %%
y = 3 * x + 7 + noise   #defining y

# %%
plt.plot(x,y,'.');   #plotting x and y in a scatter plot

# %%
m_guess = 1     #defining m_guess                                         #plotting y=mx+b
b_guess = 1     #defining b_guess

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');   #making dots red
plt.plot(x,y,'g.');         #making dots green

# %%
m_guess = 5    #defining m_guess
b_guess = 15   #defining b_guess

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');  #making dots red
plt.plot(x,y,'g.');        #making dots green

# %%
m_guess = 3    #defining m_guess
b_guess = 7    #defining b_guess

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');   #making dots red
plt.plot(x,y,'g.');         #making dots green

# %%
loss = np.sum((y_guess - y)**2)  #defining loss

# %%
loss  #the loss
# Out:
# 6284.689238933532

# %%
for m_guess in np.linspace(-10,10,10):
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
# 409636.831834826 -10.0 -10.0
# 392198.02170952834 -10.0 -7.777777777777778
# 375253.0387447248 -10.0 -5.555555555555555
# 358801.88294041494 -10.0 -3.333333333333333
# 342844.5542965989 -10.0 -1.1111111111111107
# 327381.0528132766 -10.0 1.1111111111111107
# 312411.37849044823 -10.0 3.333333333333334
# 297935.5313281137 -10.0 5.555555555555557
# 283953.5113262729 -10.0 7.777777777777779
# 270465.3184849261 -10.0 10.0
# 302131.2392206901 -7.777777777777778 -10.0
# 287161.5648978616 -7.777777777777778 -7.777777777777778
# 272685.7177355271 -7.777777777777778 -5.555555555555555
# 258703.69773368636 -7.777777777777778 -3.333333333333333
# 245215.50489233946 -7.777777777777778 -1.1111111111111107
# 232221.13921148638 -7.777777777777778 1.1111111111111107
# 219720.6006911271 -7.777777777777778 3.333333333333334
# 207713.88933126171 -7.777777777777778 5.555555555555557
# 196201.0051318901 -7.777777777777778 7.777777777777779
# 185181.9480930123 -7.777777777777778 10.0
# ...

# %%
best_loss = 100000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20):
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess 

            plt.plot(x,y_guess,'r.');
            plt.plot(x,y,'g.');
            plt.show()

            print(loss,m_guess,b_guess)
# Out:
# 98982.9589974592 -4.736842105263158 8.94736842105263
# 95425.45552474978 -4.736842105263158 10.0
# 94962.15773068486 -3.6842105263157894 2.6315789473684212
# 91293.85093387576 -3.6842105263157894 3.6842105263157894
# 87736.34746116633 -3.6842105263157894 4.7368421052631575
# 84289.64731255664 -3.6842105263157894 5.789473684210526
# 80953.75048804667 -3.6842105263157894 6.842105263157894
# 77728.65698763641 -3.6842105263157894 7.894736842105264
# 74614.36681132589 -3.6842105263157894 8.94736842105263
# 71610.87995911509 -3.6842105263157894 10.0
# 71000.59816369343 -2.6315789473684212 2.6315789473684212
# 67886.30798738291 -2.6315789473684212 3.6842105263157894
# 64882.821135172126 -2.6315789473684212 4.7368421052631575
# 61990.13760706104 -2.6315789473684212 5.789473684210526
# 59208.25740304968 -2.6315789473684212 6.842105263157894
# 56537.18052313805 -2.6315789473684212 7.894736842105264
# 53976.906967326155 -2.6315789473684212 8.94736842105263
# ...
